# %% [markdown]
# # Geoprocessing Toolkit 1

# %%
import os
import pandas as pd
import geopandas as gpd
# %matplotlib notebook
from shapely.geometry import Point, LineString, Polygon
from fiona.crs import from_epsg
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Everything above here should basically be standard at this point!!!
#
# ![duh](https://media.giphy.com/media/aVtdz7iNVPI1W/giphy.gif)
# ________________________________________

# %% [markdown]
# Aite lets change the directory!

# %%
os.chdir('data/colombia/')

# %% [markdown]
# Time to read the shapefile!! __geopandas is our library and then .read_file() is our function__
#
# ![duh](https://media.giphy.com/media/y4E6VumnBbIfm/giphy.gif)

# %%
colo_shape = gpd.read_file('gadm36_COL_1.shp')

# %% [markdown]
# Wanna check it out? Use .plot() or .head()

# %%
colo_shape.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# How about some tabular data? Go to
# * http://geo.aiddata.org/query/#!/
# * Select Colombia GADM
# * Adm 1 boundary
# * Add to Request
#     1. VIIRS Nighttime Lights - 2013 SUM
#     2. Drug Cultivation Sites
#     3. UCDP - 2014 SUM

# %% [markdown]
# And lets rename that long csv file. How about colo.csv. Don't forget to put it into the colombia folder!

# %%
colo_tab = pd.read_csv('colo.csv')

# %% [markdown]
# Who needed encoding? Remeber what it was?
#
# Hint: y tu brutus?

# %% [markdown]
# Wanna check out this data? How about .describe(), dtypes, head/tail()

# %%
colo_tab.describe()
# Out:
#          asdf_id  v4composites_calibrated_201709.2013.sum  \
# count  32.000000                                32.000000
# mean   15.500000                             45950.754482
# std     9.380832                             44597.471094
# min     0.000000                               359.000000
# 25%     7.750000                             10719.302002
# 50%    15.500000                             41485.439453
# 75%    23.250000                             60246.604492
# max    31.000000                            180695.156250
#
#        drugdata_categorical_201708.none.categorical_count  \
# count                                          32.000000
# mean                                        28964.187500
# std                                         23312.186682
# min                                            46.000000
# 25%                                         17691.500000
# 50%                                         20195.000000
# 75%                                         38531.000000
# max                                         87353.000000
#
#        drugdata_categorical_201708.none.categorical_none  \
# count                                          32.000000
# mean                                        20697.812500
# std                                         20817.793702
# min                                             0.000000
# 25%                                          6633.500000
# 50%                                         12500.000000
# 75%                                         31748.000000
# max                                         87353.000000
#
#        drugdata_categorical_201708.none.categorical_cannabis  \
# count                                           32.00000
# mean                                           182.40625
# std                                           1031.84557
# min                                              0.00000
# 25%                                              0.00000
# 50%                                              0.00000
# 75%                                              0.00000
# max                                           5837.00000
#
#        drugdata_categorical_201708.none.categorical_coca_bush  \
# count                                          32.000000
# mean                                         5719.718750
# std                                          9527.706187
# min                                             0.000000
# 25%                                             0.000000
# 50%                                           511.000000
# 75%                                          8664.750000
# max                                         41137.000000
#
#        drugdata_categorical_201708.none.categorical_opium  \
# count                                          32.000000
# mean                                         2287.875000
# std                                          4483.973625
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                          1565.000000
# max                                         14773.000000
#
#        drugdata_categorical_201708.none.categorical_mix  \
# count                                         32.000000
# mean                                          76.375000
# std                                          289.216823
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                         1578.000000
#
#        ucdp_deaths_171.2014.sum  CCN_1  Shape_Area  ID_0  CCA_1       ID_1  \
# count                 29.000000    0.0   32.000000  32.0    0.0  32.000000
# mean                   5.186207    NaN    2.896519  53.0    NaN  16.500000
# std                    7.921387    NaN    2.331093   0.0    NaN   9.380832
# min                    0.000000    NaN    0.004362  53.0    NaN   1.000000
# 25%                    0.000000    NaN    1.768622  53.0    NaN   8.750000
# 50%                    0.000000    NaN    2.019395  53.0    NaN  16.500000
# 75%                    7.000000    NaN    3.852642  53.0    NaN  24.250000
# max                   28.000000    NaN    8.734401  53.0    NaN  32.000000
#
#        Shape_Length  NL_NAME_1
# count     32.000000        0.0
# mean      11.402621        NaN
# std        5.608735        NaN
# min        0.846961        NaN
# 25%        8.211024        NaN
# 50%       10.716741        NaN
# 75%       15.208211        NaN
# max       23.775040        NaN

# %% [markdown]
# These variable names are terrible! Lets change them real quick.
#
# First we will get a list of column names.

# %%
colo_tab.columns
# Out:
# Index(['asdf_id', 'v4composites_calibrated_201709.2013.sum',
#        'drugdata_categorical_201708.none.categorical_count',
#        'drugdata_categorical_201708.none.categorical_none',
#        'drugdata_categorical_201708.none.categorical_cannabis',
#        'drugdata_categorical_201708.none.categorical_coca_bush',
#        'drugdata_categorical_201708.none.categorical_opium',
#        'drugdata_categorical_201708.none.categorical_mix',
#        'ucdp_deaths_171.2014.sum', 'CCN_1', 'NAME_0', 'Shape_Area',
#        'VARNAME_1', 'ENGTYPE_1', 'NAME_1', 'ID_0', 'HASC_1', 'CCA_1', 'ID_1',
#        'TYPE_1', 'Shape_Length', 'NL_NAME_1', 'ISO'],
#       dtype='object')

# %% [markdown]
# So its not every one that we need to change, just the ones that are long and we plan to use for some analysis.

# %%
colo_tab.rename(columns = {'v4composites_calibrated_201709.2013.sum': 'lights',
       'drugdata_categorical_201708.none.categorical_count': 'drug_count',
       'drugdata_categorical_201708.none.categorical_none': 'drug_other',
       'drugdata_categorical_201708.none.categorical_cannabis': 'herb',
       'drugdata_categorical_201708.none.categorical_coca_bush': 'coke',
       'drugdata_categorical_201708.none.categorical_opium': 'heroin',
       'drugdata_categorical_201708.none.categorical_mix': 'drug_mix',
       'ucdp_deaths_171.2014.sum': 'ucdp_deaths'}, inplace = True)

# %% [markdown]
# Pretty easy right?!?!?
#
# ![chill](https://media.giphy.com/media/TlK63Euc9KArc2a0kEw/giphy.gif)

# %% [markdown]
# Lets merge the two!
#
# What column matches up between the shapefile and the tabular file?

# %%
colo_tab.head()
# Out:
#    asdf_id         lights  drug_count  drug_other  herb   coke  heroin  \
# 0        0    1013.670061       87353       87353     0      0       0
# 1        1  151073.993896       51678       43210     0   8465       3
# 2        2   11489.069336       20725        9290     0  11435       0
# 3        3   54602.371094        3647        3647     0      0       0
# 4        4   52571.370117       21386        8088     0  13298       0
#
#    drug_mix  ucdp_deaths  CCN_1    NAME_0  Shape_Area VARNAME_1    ENGTYPE_1  \
# 0         0          2.0    NaN  Colombia    8.734401       NaN  Commissiary
# 1         0         17.0    NaN  Colombia    5.168365       NaN   Department
# 2         0         28.0    NaN  Colombia    2.071644       NaN   Intendancy
# 3         0          0.0    NaN  Colombia    0.364899       NaN   Department
# 4         0          0.0    NaN  Colombia    2.139413       NaN   Department
#
#       NAME_1  ID_0 HASC_1  CCA_1  ID_1        TYPE_1  Shape_Length  NL_NAME_1  \
# 0   Amazonas    53  CO.AM    NaN     1     Comisaría     23.775040        NaN
# 1  Antioquia    53  CO.AN    NaN     2  Departamento     19.141026        NaN
# 2     Arauca    53  CO.AR    NaN     3   Intendencia      7.906898        NaN
# 3  Atlántico    53  CO.AT    NaN     4  Departamento      3.285024        NaN
# 4    Bolívar    53  CO.BL    NaN     5  Departamento     13.922045        NaN
#
#    ISO
# 0  COL
# 1  COL
# 2  COL
# 3  COL
# 4  COL

# %%
colo_shape.head()
# Out:
#   GID_0    NAME_0    GID_1     NAME_1 VARNAME_1 NL_NAME_1        TYPE_1  \
# 0   COL  Colombia  COL.1_1   Amazonas      None      None     Comisaría
# 1   COL  Colombia  COL.2_1  Antioquia      None      None  Departamento
# 2   COL  Colombia  COL.3_1     Arauca      None      None   Intendencia
# 3   COL  Colombia  COL.4_1  Atlántico      None      None  Departamento
# 4   COL  Colombia  COL.5_1    Bolívar      None      None  Departamento
#
#      ENGTYPE_1  CC_1 HASC_1                                           geometry
# 0  Commissiary  None  CO.AM  (POLYGON ((-69.43138123 -1.07847404, -69.42711...
# 1   Department  None  CO.AN  (POLYGON ((-76.99986267 8.999860760000001, -77...
# 2   Intendancy  None  CO.AR  POLYGON ((-69.92316436999999 6.05792284, -69.9...
# 3   Department  None  CO.AT  POLYGON ((-74.88159942999999 10.3409996, -74.8...
# 4   Department  None  CO.BL  (POLYGON ((-75.79680634 10.1679163, -75.796806...

# %%
colombia = colo_shape.merge(colo_tab, on='HASC_1', how='left')

# %%
colombia.head()
# Out:
#   GID_0  NAME_0_x    GID_1   NAME_1_x VARNAME_1_x NL_NAME_1_x      TYPE_1_x  \
# 0   COL  Colombia  COL.1_1   Amazonas        None        None     Comisaría
# 1   COL  Colombia  COL.2_1  Antioquia        None        None  Departamento
# 2   COL  Colombia  COL.3_1     Arauca        None        None   Intendencia
# 3   COL  Colombia  COL.4_1  Atlántico        None        None  Departamento
# 4   COL  Colombia  COL.5_1    Bolívar        None        None  Departamento
#
#    ENGTYPE_1_x  CC_1 HASC_1  \
# 0  Commissiary  None  CO.AM
# 1   Department  None  CO.AN
# 2   Intendancy  None  CO.AR
# 3   Department  None  CO.AT
# 4   Department  None  CO.BL
#
#                                             geometry  asdf_id         lights  \
# 0  (POLYGON ((-69.43138123 -1.07847404, -69.42711...        0    1013.670061
# 1  (POLYGON ((-76.99986267 8.999860760000001, -77...        1  151073.993896
# 2  POLYGON ((-69.92316436999999 6.05792284, -69.9...        2   11489.069336
# 3  POLYGON ((-74.88159942999999 10.3409996, -74.8...        3   54602.371094
# 4  (POLYGON ((-75.79680634 10.1679163, -75.796806...        4   52571.370117
#
#    drug_count  drug_other  herb   coke  heroin  drug_mix  ucdp_deaths  CCN_1  \
# 0       87353       87353     0      0       0         0          2.0    NaN
# 1       51678       43210     0   8465       3         0         17.0    NaN
# 2       20725        9290     0  11435       0         0         28.0    NaN
# 3        3647        3647     0      0       0         0          0.0    NaN
# 4       21386        8088     0  13298       0         0          0.0    NaN
#
#    NAME_0_y  Shape_Area VARNAME_1_y  ENGTYPE_1_y   NAME_1_y  ID_0  CCA_1  \
# 0  Colombia    8.734401         NaN  Commissiary   Amazonas    53    NaN
# 1  Colombia    5.168365         NaN   Department  Antioquia    53    NaN
# 2  Colombia    2.071644         NaN   Intendancy     Arauca    53    NaN
# 3  Colombia    0.364899         NaN   Department  Atlántico    53    NaN
# 4  Colombia    2.139413         NaN   Department    Bolívar    53    NaN
#
#    ID_1      TYPE_1_y  Shape_Length  NL_NAME_1_y  ISO
# 0     1     Comisaría     23.775040          NaN  COL
# 1     2  Departamento     19.141026          NaN  COL
# 2     3   Intendencia      7.906898          NaN  COL
# 3     4  Departamento      3.285024          NaN  COL
# 4     5  Departamento     13.922045          NaN  COL

# %% [markdown]
# Nice now we can get into actually looking at the data and using some of our geoprocessing tools!

# %% [markdown]
# # Selection

# %% [markdown]
# Remember we can use selection to get information about certain spatial objects or the distribution of data within these groups.
#
# Lets start by selecting which of the first administrative districts in Colombia, also known as Departments, contains the capital.
#
# 1. Go to https://www.google.com/maps
# 2. Type in the capital of Colombia (World Geography quiz!)
# 3. Right click on the city name (or center)
# 4. Click What's here?
# 5. Input the latitude and longitude as a point!

# %% [markdown]
# Lets make it as a pandas dataframe and use the same techique to make it a geodataframe too.

# %%
data = {'city':['Bogota'], 'latitude':[4.5709], 'longitude':[-74.2973]}

# %%
cities = pd.DataFrame(data)
city_geometry = [Point(xy) for xy in zip(cities.longitude, cities.latitude)]
city_gdf = gpd.GeoDataFrame(cities, geometry = city_geometry)

# %%
colombia.crs = from_epsg(3006)
city_gdf.crs = from_epsg(3006)

# %%
fig, ax = plt.subplots()
colombia.plot(ax=ax, facecolor='gray');
city_gdf.plot(ax=ax,color='red');
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ![alrighty](https://media.giphy.com/media/5hc2bkC60heU/giphy.gif)

# %% [markdown]
# So we can see that the point for Bogota is in fact, within Colombia. How about we select the department it is within.

# %%
for index, row in colombia.iterrows():
    if city_gdf.within(row['geometry']).any():
        print(row['NAME_1_x'])
# Out:
# Cundinamarca

# %% [markdown]
# Interesante! So now we know the department which has the capital city and we didn't even have to use google.
#
# We did the previous selection using a geospatial __location__ technique.
#
# Since we know the name of the department, now we can use an __attribute__ selection.

# %%
cundinamarca = colombia.loc[colombia.NAME_1_x == "Cundinamarca"]

# %%
cundinamarca
# Out:
#    GID_0  NAME_0_x     GID_1      NAME_1_x VARNAME_1_x NL_NAME_1_x  \
# 13   COL  Colombia  COL.14_1  Cundinamarca        None        None
#
#         TYPE_1_x ENGTYPE_1_x  CC_1 HASC_1  \
# 13  Departamento  Department  None  CO.CU
#
#                                              geometry  asdf_id        lights  \
# 13  POLYGON ((-73.13569640999999 4.64760113, -73.1...       13  180695.15625
#
#     drug_count  drug_other  herb  coke  heroin  drug_mix  ucdp_deaths  CCN_1  \
# 13       19923       19923     0     0       0         0          0.0    NaN
#
#     NAME_0_y  Shape_Area VARNAME_1_y ENGTYPE_1_y      NAME_1_y  ID_0  CCA_1  \
# 13  Colombia     1.99299         NaN  Department  Cundinamarca    53    NaN
#
#     ID_1      TYPE_1_y  Shape_Length  NL_NAME_1_y  ISO
# 13    14  Departamento      8.582517          NaN  COL

# %% [markdown]
# Nice! We have now done selection by both location and attribute. Lets move on to buffers.

# %% [markdown]
# # Buffers

# %% [markdown]
# So if we notice, the district of Bogota has no deaths recorded in 2014 within the UCDP data.  But that does not neccisarily mean violence is not proximate to the capital.  How about we buffer the city by some kilometers and see what the other districts look like.

# %%
city_copy = city_gdf.copy()
city_copy['geometry'] = city_copy.geometry.buffer(2)

# %%
fig, ax = plt.subplots()
colombia.plot(ax=ax, facecolor='gray');
city_copy.plot(ax=ax,color='red');
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for index, row in colombia.iterrows():
    if city_copy.intersects(row['geometry']).any():
        print("'" + str(row['NAME_1_x']) + "'")
# Out:
# 'Antioquia'
# 'Boyacá'
# 'Caldas'
# 'Caquetá'
# 'Casanare'
# 'Chocó'
# 'Cundinamarca'
# 'Huila'
# 'Meta'
# 'Quindío'
# 'Risaralda'
# 'Santander'
# 'Tolima'
# 'Valle del Cauca'

# %%
depts= ['Antioquia','Boyacá', 'Caldas','Caquetá','Casanare',
        'Chocó','Cundinamarca','Huila','Meta','Quindío',
        'Risaralda','Santander','Tolima','Valle del Cauca'
       ]

# %%
depts_bogota = colombia.loc[colombia.NAME_1_x.isin(depts)]

# %%
depts_bogota
# Out:
#    GID_0  NAME_0_x     GID_1         NAME_1_x VARNAME_1_x NL_NAME_1_x  \
# 1    COL  Colombia   COL.2_1        Antioquia        None        None
# 5    COL  Colombia   COL.6_1           Boyacá        None        None
# 6    COL  Colombia   COL.7_1           Caldas        None        None
# 7    COL  Colombia   COL.8_1          Caquetá        None        None
# 8    COL  Colombia   COL.9_1         Casanare        None        None
# 11   COL  Colombia  COL.12_1            Chocó        None        None
# 13   COL  Colombia  COL.14_1     Cundinamarca        None        None
# 16   COL  Colombia  COL.17_1            Huila        None        None
# 19   COL  Colombia  COL.20_1             Meta        None        None
# 23   COL  Colombia  COL.24_1          Quindío        None        None
# 24   COL  Colombia  COL.25_1        Risaralda        None        None
# 26   COL  Colombia  COL.27_1        Santander        None        None
# 28   COL  Colombia  COL.29_1           Tolima        None        None
# 29   COL  Colombia  COL.30_1  Valle del Cauca       Valle        None
#
#         TYPE_1_x ENGTYPE_1_x  CC_1 HASC_1  \
# 1   Departamento  Department  None  CO.AN
# 5   Departamento  Department  None  CO.BY
# 6   Departamento  Department  None  CO.CL
# 7    Intendencia  Intendancy  None  CO.CQ
# 8    Intendencia  Intendancy  None  CO.CS
# 11  Departamento  Department  None  CO.CH
# 13  Departamento  Department  None  CO.CU
# 16  Departamento  Department  None  CO.HU
# 19  Departamento  Department  None  CO.ME
# 23  Departamento  Department  None  CO.QD
# 24  Departamento  Department  None  CO.RI
# 26  Departamento  Department  None  CO.ST
# 28  Departamento  Department  None  CO.TO
# 29  Departamento  Department  None  CO.VC
#
#                                              geometry  asdf_id         lights  \
# 1   (POLYGON ((-76.99986267 8.999860760000001, -77...        1  151073.993896
# 5   POLYGON ((-74.21579742 5.4612999, -74.2181015 ...        5   64905.050781
# 6   POLYGON ((-75.35690308 4.89080095, -75.3534011...        7   34850.699219
# 7   POLYGON ((-73.88365173 -0.43055901, -73.886199...        8    8410.000000
# 8   POLYGON ((-72.63629913 4.28270006, -72.6455001...        9   45913.351562
# 11  (POLYGON ((-77.38069152999999 4.37347078, -77....       12    4946.160126
# 13  POLYGON ((-73.13569640999999 4.64760113, -73.1...       13  180695.156250
# 16  POLYGON ((-76.13250732 1.49347103, -76.1348037...       16   52760.949219
# 19  POLYGON ((-73.66020202999999 1.610901, -73.686...       19   67754.566406
# 23  POLYGON ((-75.66320038000001 4.24170113, -75.6...       23   18367.949219
# 24  POLYGON ((-75.74590302 4.70870018, -75.7534027...       24   28210.480469
# 26  POLYGON ((-72.64330292 6.41940117, -72.6507034...       26   94672.578125
# 28  POLYGON ((-74.80899811 3.49300003, -74.8072967...       28   69998.054688
# 29  (POLYGON ((-78.21541594999999 2.94263911, -78....       29  142465.890625
#
#     drug_count  drug_other  herb   coke  heroin  drug_mix  ucdp_deaths  CCN_1  \
# 1        51678       43210     0   8465       3         0         17.0    NaN
# 5        19084       19084     0      0       0         0          0.0    NaN
# 6         6157        2692     0      0    3465         0          0.0    NaN
# 7        73269       45347     0  27879      41         2          5.0    NaN
# 8        36404       36359     0     45       0         0          0.0    NaN
# 11       36953       36953     0      0       0         0          6.0    NaN
# 13       19923       19923     0      0       0         0          0.0    NaN
# 16       16523        1776     0    405   13891       451          0.0    NaN
# 19       69408       28267     0  41137       4         0         25.0    NaN
# 23        1410           0     0      0    1410         0          0.0    NaN
# 24        3299        1269     0      0    2030         0          0.0    NaN
# 26       24768       24768     0      0       0         0          1.0    NaN
# 28       19061        6994     0      0   12067         0         11.0    NaN
# 29       17908        6955     0    720   10048       185          3.0    NaN
#
#     NAME_0_y  Shape_Area VARNAME_1_y ENGTYPE_1_y         NAME_1_y  ID_0  \
# 1   Colombia    5.168365         NaN  Department        Antioquia    53
# 5   Colombia    1.908535         NaN  Department           Boyacá    53
# 6   Colombia    0.616329         NaN  Department           Caldas    53
# 7   Colombia    7.324507         NaN  Intendancy          Caquetá    53
# 8   Colombia    3.640810         NaN  Intendancy         Casanare    53
# 11  Colombia    3.694846         NaN  Department            Chocó    53
# 13  Colombia    1.992990         NaN  Department     Cundinamarca    53
# 16  Colombia    1.650928         NaN  Department            Huila    53
# 19  Colombia    6.943740         NaN  Department             Meta    53
# 23  Colombia    0.141012         NaN  Department          Quindío    53
# 24  Colombia    0.329331         NaN  Department        Risaralda    53
# 26  Colombia    2.476726         NaN  Department        Santander    53
# 28  Colombia    1.906482         NaN  Department           Tolima    53
# 29  Colombia    1.791487       Valle  Department  Valle del Cauca    53
#
#     CCA_1  ID_1      TYPE_1_y  Shape_Length  NL_NAME_1_y  ISO
# 1     NaN     2  Departamento     19.141026          NaN  COL
# 5     NaN     6  Departamento     12.360546          NaN  COL
# 6     NaN     8  Departamento      5.458548          NaN  COL
# 7     NaN     9   Intendencia     17.014369          NaN  COL
# 8     NaN    10   Intendencia      9.940841          NaN  COL
# 11    NaN    13  Departamento     23.394558          NaN  COL
# 13    NaN    14  Departamento      8.582517          NaN  COL
# 16    NaN    17  Departamento      8.377296          NaN  COL
# 19    NaN    20  Departamento     15.156743          NaN  COL
# 23    NaN    24  Departamento      1.876727          NaN  COL
# 24    NaN    25  Departamento      3.943389          NaN  COL
# 26    NaN    27  Departamento      9.372878          NaN  COL
# 28    NaN    29  Departamento      7.699065          NaN  COL
# 29    NaN    30  Departamento     16.179572          NaN  COL
