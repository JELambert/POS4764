# %%
import os
import pandas as pd
import geopandas as gpd

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'gadm36_USA_0.cpg',
#  'gadm36_USA_0.dbf',
#  'gadm36_USA_0.prj',
#  'gadm36_USA_0.shp',
#  'gadm36_USA_0.shx',
#  'gadm36_USA_1.cpg',
#  'gadm36_USA_1.dbf',
#  'gadm36_USA_1.prj',
#  'gadm36_USA_1.shp',
#  'gadm36_USA_1.shx',
#  'gadm36_USA_2.cpg',
#  'gadm36_USA_2.dbf',
#  'gadm36_USA_2.prj',
#  'gadm36_USA_2.shp',
#  'gadm36_USA_2.shx',
#  'incarceration_trends.csv',
#  'license.txt',
#  'prison people jupyter notebook.ipynb']

# %%
jail = pd.read_csv('incarceration_trends.csv')

# %%
jail.head()
# Out:
#        yfips  year  fips state     county_name  total_pop  total_pop_15to64  \
# 0  197001001  1970  1001    AL  Autauga County      24661             14154
# 1  197101001  1971  1001    AL  Autauga County      25503             14765
# 2  197201001  1972  1001    AL  Autauga County      27156             15939
# 3  197301001  1973  1001    AL  Autauga County      28453             16906
# 4  197401001  1974  1001    AL  Autauga County      29261             17578
#
#    female_pop_15to64  male_pop_15to64  aapi_pop_15to64  black_pop_15to64  \
# 0               7293             6861              NaN               NaN
# 1               7585             7180              NaN               NaN
# 2               8168             7771              NaN               NaN
# 3               8651             8255              NaN               NaN
# 4               8992             8586              NaN               NaN
#
# ...

# %%
counties = gpd.read_file('gadm36_USA_2.shp')

# %%
counties.plot()
# Out:
# <img src="data:image/png;base64,..." width="742.4">

# %%
# %matplotlib notebook

# %%
counties.head()
# Out:
#   GID_0         NAME_0    GID_1   NAME_1 NL_NAME_1      GID_2   NAME_2  \
# 0   USA  United States  USA.1_1  Alabama      None  USA.1.1_1  Autauga
# 1   USA  United States  USA.1_1  Alabama      None  USA.1.2_1  Baldwin
# 2   USA  United States  USA.1_1  Alabama      None  USA.1.3_1  Barbour
# 3   USA  United States  USA.1_1  Alabama      None  USA.1.4_1     Bibb
# 4   USA  United States  USA.1_1  Alabama      None  USA.1.5_1   Blount
#
#   VARNAME_2 NL_NAME_2  TYPE_2 ENGTYPE_2  CC_2    HASC_2  \
# 0      None      None  County    County  None  US.AL.AU
# 1      None      None  County    County  None  US.AL.BD
# 2      None      None  County    County  None  US.AL.BR
# 3      None      None  County    County  None  US.AL.BI
# 4      None      None  County    County  None  US.AL.BU
#
#                                             geometry
# 0  POLYGON ((-86.81896209716791 32.34027099609386...
# 1  (POLYGON ((-87.51055908203125 30.3397216796875...
# ...

# %%
print(list(jail.county_name.unique()))
# Out:
# ['Autauga County', 'Baldwin County', 'Barbour County', 'Bibb County', 'Blount County', 'Bullock County', 'Butler County', 'Calhoun County', 'Chambers County', 'Cherokee County', 'Chilton County', 'Choctaw County', 'Clarke County', 'Clay County', 'Cleburne County', 'Coffee County', 'Colbert County', 'Conecuh County', 'Coosa County', 'Covington County', 'Crenshaw County', 'Cullman County', 'Dale County', 'Dallas County', 'DeKalb County', 'Elmore County', 'Escambia County', 'Etowah County', 'Fayette County', 'Franklin County', 'Geneva County', 'Greene County', 'Hale County', 'Henry County', 'Houston County', 'Jackson County', 'Jefferson County', 'Lamar County', 'Lauderdale County', 'Lawrence County', 'Lee County', 'Limestone County', 'Lowndes County', 'Macon County', 'Madison County', 'Marengo County', 'Marion County', 'Marshall County', 'Mobile County', 'Monroe County', 'Montgomery County', 'Morgan County', 'Perry County', 'Pickens County', 'Pike County', 'Randolph County', 'Russell Co
# ...

# %%
florida = jail.loc[jail.state == "FL"]

# %%
florida79 = florida.loc[florida.year== 1979]

# %%
florida79['NAME_2'] = florida79['county_name'].str.replace(" County", "").replace(" ", "")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
fl_counties = counties.loc[counties.NAME_1 == "Florida"]

# %%
fl_counties.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fl_inc = fl_counties.merge(florida79, on='NAME_2', how='left')

# %%
fl_inc
# Out:
#    GID_0         NAME_0     GID_1   NAME_1 NL_NAME_1        GID_2  \
# 0    USA  United States  USA.10_1  Florida      None   USA.10.1_1
# 1    USA  United States  USA.10_1  Florida      None   USA.10.2_1
# 2    USA  United States  USA.10_1  Florida      None   USA.10.3_1
# 3    USA  United States  USA.10_1  Florida      None   USA.10.4_1
# 4    USA  United States  USA.10_1  Florida      None   USA.10.5_1
# 5    USA  United States  USA.10_1  Florida      None   USA.10.6_1
# 6    USA  United States  USA.10_1  Florida      None   USA.10.7_1
# 7    USA  United States  USA.10_1  Florida      None   USA.10.8_1
# 8    USA  United States  USA.10_1  Florida      None   USA.10.9_1
# 9    USA  United States  USA.10_1  Florida      None  USA.10.10_1
# 10   USA  United States  USA.10_1  Florida      None  USA.10.11_1
# 11   USA  United States  USA.10_1  Florida      None  USA.10.12_1
# 12   USA  United States  USA.10_1  Florida      None  USA.10.13_1
# ...

# %%
fl_inc.male_adult_jail_pop.fillna(0,inplace=True)

# %%
fl_inc.plot(column='male_adult_jail_pop', legend=True)
plt.title("1979")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'1979')

# %%
import matplotlib.pyplot as plt

# %%
florida['NAME_2'] = florida['county_name'].str.replace(" County", "").replace(" ", "")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
florida.head()
# Out:
#            yfips  year   fips state     county_name  total_pop  \
# 15408  197012001  1970  12001    FL  Alachua County     105582
# 15409  197112001  1971  12001    FL  Alachua County     108875
# 15410  197212001  1972  12001    FL  Alachua County     119776
# 15411  197312001  1973  12001    FL  Alachua County     125907
# 15412  197412001  1974  12001    FL  Alachua County     131229
#
#        total_pop_15to64  female_pop_15to64  male_pop_15to64  aapi_pop_15to64  \
# 15408             71298              35548            35750              NaN
# 15409             74145              36919            37226              NaN
# 15410             82392              41130            41262              NaN
# 15411             87413              43689            43724              NaN
# 15412             92158              46035            46123              NaN
#
#        black_pop_15to64  latinx_pop_15to64  native_pop_15to64  \
# ...

# %%
florida.male_adult_jail_pop.fillna(0,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
full_florida = fl_counties.merge(florida, on='NAME_2', how='left')

# %%
len(full_florida)
# Out:
# 3075

# %%
years = list(full_florida.year.unique())

# %%
years
# Out:
# [1970.0,
#  1971.0,
#  1972.0,
#  1973.0,
#  1974.0,
#  1975.0,
#  1976.0,
#  1977.0,
#  1978.0,
#  1979.0,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  2017.0,
#  nan]

# %%
# %matplotlib inline

# %%
for year in years:
    
    fl_year = full_florida.loc[full_florida.year== year]
    
    fl_year.plot(column='male_adult_jail_pop', legend=True)
    plt.title(str(year))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\plotting.py:405: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   "empty. Nothing has been displayed.", UserWarning)
